# %%
import pandas as pd
import numpy as np

# %%
student_performance=pd.read_csv('student_performance_updated_1000.csv')
student_performance
# Out:
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female             NaN               18.0
# ..         ...             ...     ...             ...                ...
# 995        NaN  Kenneth Murray    Male            85.0               20.0
# 996     4497.0       Amy Stout  Female            91.0                NaN
# 997     1886.0             NaN    Male            85.0                8.0
# 998     7636.0  Joseph Sherman    Male            88.0               17.0
# 999     8021.0     Maria Walls  Female            88.0               10.0
#
#      PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# ...

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  960 non-null    float64
#  1   Name                       966 non-null    object
#  2   Gender                     952 non-null    object
#  3   AttendanceRate             960 non-null    float64
#  4   StudyHoursPerWeek          950 non-null    float64
#  5   PreviousGrade              967 non-null    float64
#  6   ExtracurricularActivities  957 non-null    float64
#  7   ParentalSupport            978 non-null    object
#  8   FinalGrade                 960 non-null    float64
#  9   Study Hours                976 non-null    float64
#  10  Attendance (%)             959 non-null    float64
#  11  Online Classes Taken       975 non-null    object
# dtypes: float64(8), object(4)
# memory usage: 93.9+ KB

# %%
student_performance.isna().sum()
# Out:
# StudentID                    40
# Name                         34
# Gender                       48
# AttendanceRate               40
# StudyHoursPerWeek            50
# PreviousGrade                33
# ExtracurricularActivities    43
# ParentalSupport              22
# FinalGrade                   40
# Study Hours                  24
# Attendance (%)               41
# Online Classes Taken         25
# dtype: int64

# %%
student_performance.duplicated().value_counts()
# Out:
# False    1000
# dtype: int64

# %%
#removing rows with null values
student_performance=student_performance.dropna(subset=['Name','StudentID','Gender'])

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  882 non-null    float64
#  1   Name                       882 non-null    object
#  2   Gender                     882 non-null    object
#  3   AttendanceRate             846 non-null    float64
#  4   StudyHoursPerWeek          840 non-null    float64
#  5   PreviousGrade              851 non-null    float64
#  6   ExtracurricularActivities  842 non-null    float64
#  7   ParentalSupport            862 non-null    object
#  8   FinalGrade                 846 non-null    float64
#  9   Study Hours                862 non-null    float64
#  10  Attendance (%)             844 non-null    float64
#  11  Online Classes Taken       860 non-null    object
# dtypes: float64(8), object(4)
# memory usage: 89.6+ KB

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate               36
# StudyHoursPerWeek            42
# PreviousGrade                31
# ExtracurricularActivities    40
# ParentalSupport              20
# FinalGrade                   36
# Study Hours                  20
# Attendance (%)               38
# Online Classes Taken         22
# dtype: int64

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  882 non-null    float64
#  1   Name                       882 non-null    object
#  2   Gender                     882 non-null    object
#  3   AttendanceRate             846 non-null    float64
#  4   StudyHoursPerWeek          840 non-null    float64
#  5   PreviousGrade              851 non-null    float64
#  6   ExtracurricularActivities  842 non-null    float64
#  7   ParentalSupport            862 non-null    object
#  8   FinalGrade                 846 non-null    float64
#  9   Study Hours                862 non-null    float64
#  10  Attendance (%)             844 non-null    float64
#  11  Online Classes Taken       860 non-null    object
# dtypes: float64(8), object(4)
# memory usage: 89.6+ KB

# %%
student_performance
# Out:
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female             NaN               18.0
# ..         ...             ...     ...             ...                ...
# 993     3592.0  Monica Johnson  Female            90.0               25.0
# 994     2787.0  Shannon Porter    Male            78.0               20.0
# 996     4497.0       Amy Stout  Female            91.0                NaN
# 998     7636.0  Joseph Sherman    Male            88.0               17.0
# 999     8021.0     Maria Walls  Female            88.0               10.0
#
#      PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# ...

# %%
attendance_mean=student_performance['AttendanceRate'].mean()
attendance_mean=round(attendance_mean)
attendance_mean
# Out:
# 85.0

# %%
#filling null values in AttendanceRate with the mean value
student_performance['AttendanceRate']=student_performance['AttendanceRate'].fillna(attendance_mean)
student_performance
# Out:
# <ipython-input-102-46f0fcc2bbbf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['AttendanceRate']=student_performance['AttendanceRate'].fillna(attendance_mean)
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate                0
# StudyHoursPerWeek            42
# PreviousGrade                31
# ExtracurricularActivities    40
# ParentalSupport              20
# FinalGrade                   36
# Study Hours                  20
# Attendance (%)               38
# Online Classes Taken         22
# dtype: int64

# %%
study_time_mean=student_performance['StudyHoursPerWeek'].mean()
study_time_mean.round()
# Out:
# 18.0

# %%
student_performance['StudyHoursPerWeek']=student_performance['StudyHoursPerWeek'].fillna(study_time_mean.round())
student_performance
# Out:
# <ipython-input-105-372b8d80d844>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['StudyHoursPerWeek']=student_performance['StudyHoursPerWeek'].fillna(study_time_mean.round())
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate                0
# StudyHoursPerWeek             0
# PreviousGrade                31
# ExtracurricularActivities    40
# ParentalSupport              20
# FinalGrade                   36
# Study Hours                  20
# Attendance (%)               38
# Online Classes Taken         22
# dtype: int64

# %%
student_performance['ParentalSupport'].mode()
# Out:
# 0    High
# dtype: object

# %%
student_performance['ParentalSupport'].value_counts()
# Out:
# High      308
# Medium    280
# Low       274
# Name: ParentalSupport, dtype: int64

# %%
student_performance['ParentalSupport']=student_performance['ParentalSupport'].fillna('High')
student_performance
# Out:
# <ipython-input-109-e39bda31e61a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['ParentalSupport']=student_performance['ParentalSupport'].fillna('High')
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate                0
# StudyHoursPerWeek             0
# PreviousGrade                31
# ExtracurricularActivities    40
# ParentalSupport               0
# FinalGrade                   36
# Study Hours                  20
# Attendance (%)               38
# Online Classes Taken         22
# dtype: int64

# %%
student_performance['FinalGrade']=student_performance['FinalGrade'].fillna(80)
student_performance
# Out:
# <ipython-input-111-649ddb3bce43>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['FinalGrade']=student_performance['FinalGrade'].fillna(80)
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate                0
# StudyHoursPerWeek             0
# PreviousGrade                31
# ExtracurricularActivities    40
# ParentalSupport               0
# FinalGrade                    0
# Study Hours                  20
# Attendance (%)               38
# Online Classes Taken         22
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
previous_mean=student_performance['PreviousGrade'].mean()
previous_mean.round()
# Out:
# 78.0

# %%
student_performance['PreviousGrade']=student_performance['PreviousGrade'].fillna(previous_mean.round())
student_performance
# Out:
# <ipython-input-116-8242fb428e8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['PreviousGrade']=student_performance['PreviousGrade'].fillna(previous_mean.round())
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate                0
# StudyHoursPerWeek             0
# PreviousGrade                 0
# ExtracurricularActivities    40
# ParentalSupport               0
# FinalGrade                    0
# Study Hours                  20
# Attendance (%)               38
# Online Classes Taken         22
# dtype: int64

# %%
student_performance['ExtracurricularActivities'].value_counts()
# Out:
# 1.0    254
# 2.0    236
# 3.0    186
# 0.0    166
# Name: ExtracurricularActivities, dtype: int64

# %%
student_performance['ExtracurricularActivities'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
student_performance['ExtracurricularActivities']=student_performance['ExtracurricularActivities'].fillna('1')
student_performance
# Out:
# <ipython-input-120-e019d07b9931>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['ExtracurricularActivities']=student_performance['ExtracurricularActivities'].fillna('1')
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate                0
# StudyHoursPerWeek             0
# PreviousGrade                 0
# ExtracurricularActivities     0
# ParentalSupport               0
# FinalGrade                    0
# Study Hours                  20
# Attendance (%)               38
# Online Classes Taken         22
# dtype: int64

# %%
student_performance['Study Hours'].median()
# Out:
# 2.5

# %%
student_performance['Study Hours']=student_performance['Study Hours'].fillna(2.5)
student_performance
# Out:
# <ipython-input-127-522a1e109fbc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['Study Hours']=student_performance['Study Hours'].fillna(2.5)
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate                0
# StudyHoursPerWeek             0
# PreviousGrade                 0
# ExtracurricularActivities     0
# ParentalSupport               0
# FinalGrade                    0
# Study Hours                   0
# Attendance (%)               38
# Online Classes Taken         22
# dtype: int64

# %%
student_performance['Online Classes Taken'].value_counts()
# Out:
# True     431
# False    429
# Name: Online Classes Taken, dtype: int64

# %%
student_performance['Online Classes Taken']=student_performance['Online Classes Taken'].fillna('True')
student_performance
# Out:
# <ipython-input-132-7954c1a0659e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['Online Classes Taken']=student_performance['Online Classes Taken'].fillna('True')
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                     0
# Name                          0
# Gender                        0
# AttendanceRate                0
# StudyHoursPerWeek             0
# PreviousGrade                 0
# ExtracurricularActivities     0
# ParentalSupport               0
# FinalGrade                    0
# Study Hours                   0
# Attendance (%)               38
# Online Classes Taken          0
# dtype: int64

# %%
attend_student = student_performance['Attendance (%)'].mean()
attend_student = attend_student.round()
attend_student
# Out:
# 77.0

# %%
student_performance['Attendance (%)']=student_performance['Attendance (%)'].fillna(attend_student)
student_performance
# Out:
# <ipython-input-145-78644b0651dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_performance['Attendance (%)']=student_performance['Attendance (%)'].fillna(attend_student)
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            85.0               18.0
# ..         ...             ...     ...             ...                ...
# ...

# %%
student_performance.isna().sum()
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# Study Hours                  0
# Attendance (%)               0
# Online Classes Taken         0
# dtype: int64

# %%
figsize=(11,8)
sns.boxplot(data=student_performance, x='FinalGrade')       
plt.title('Boxplot of Final Grades')
plt.xlabel('Final Grade')
plt.show()

# %%
#plotting histogram to see distribution of final grades
plt.figure(figsize=(11,8))
sns.histplot(data=student_performance, x='FinalGrade', bins=20, kde=True)
plt.title('Distribution of Final Grades')   
plt.xlabel('Final Grade')
plt.show()
